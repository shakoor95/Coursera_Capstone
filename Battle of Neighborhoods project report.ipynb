# %% [markdown]
# # Battle of Neighborhoods-Coursera Capstone Project

# %% [markdown]
# # Introduction
#
# This project analyzes neighborhoods of New York City in respects of all major venues of neighborhoods in any borough and rental analysis. New York City is very diverse and multicultural city. NYC has been distributed over a land of 302.6 square miles as per wiki.
# This city consists of 5 boroughs as:
# Brooklyn
# Manhattan
# Queens
# Staten Island
# Bronx
#
# New York City is also the most densely populated major city in the United States. Located at the southern tip of the state of New York, the city is the center of the New York metropolitan area, the largest metropolitan area in the world by urban landmass and one of the world's most populous megacities, with an estimated 20,320,876 people in its 2017 Metropolitan Statistical Area and 23,876,155 residents in its Combined Statistical Area. A global power city, New York City has been described as the cultural, financial, and media capital of the world, and exerts a significant impact upon commerce, entertainment, research, technology, education, politics, tourism, art, fashion, and sports. The city's fast pace has inspired the term New York minute. Home to the headquarters of the United Nations, New York is an important center for international diplomacy.
#
# This project surely proves very helpful for any visitor or employee or student who comes to this great city with intention to live here.

# %% [markdown]
# # Objective
#
# Objective of this project is that anyone who is visiting NYC will get deep insight of new york city and he/she will get intouch with it's neighborhoods and rents at most of places. Moreover, will get fimilar with venues that we got using Foursquare.

# %% [markdown]
# # Discussion
#
# Let’s discuss the above mentioned problem. As New York city have 5 boroughs and each borough have its own neighborhoods. So, let’s say John got a job or he is a student that’s why he is planning to move New York city. Before coming here, he should have rough idea about the rents going in the city. That’s why we have to scrap the data from different sites to get approx. average rents for various neighborhoods. Once he’ll get familiar with neighborhoods and their rents, then it’s time for him to decide which neighborhood will better match with his everyday needs. For this reason, we have to introduce data for NYC and have to use Foursquare API to get venues. Let’s say we’ll explore Brooklyn,NY in this problem. So we should have longitude/latitude of Brooklyn. Then we have to develop data sets of every neighborhood. Then we have to find out each neighborhood have which restaurant, café, coffee shops, gyms different cuisines as NYC is multicultural city.
# Before getting started we’ll need these libraries such as folium, pandas, numpy, geopy, json and matplotlib etc.
#
#
# ** I have uploaded .csv files and json files that we’ll use in this project.

# %% [markdown]
# # Data Description
# In this project we have used the following data:
#
# Gathered data for following boroughs of New York city using beautifulsoap and stored thier respective .csv files at the following websites.
#
# Brooklyn (https://github.com/shakoor95/Coursera_Capstone/blob/master/brooklyn.csv)
#
# Manhattan(https://github.com/shakoor95/Coursera_Capstone/blob/master/manhattan.csv)
#
# Bronx(https://github.com/shakoor95/Coursera_Capstone/blob/master/bronx.csv)
#
#
# If anyone is intersted in visiting rental data website he/she can visit to get data of cities all over the United States:
#
# https://www.rentcafe.com/average-rent-market-trends/us/ny/brooklyn/
# https://www.rentcafe.com/average-rent-market-trends/us/ny/manhattan/
# https://www.rentcafe.com/average-rent-market-trends/us/ny/bronx/
#
# But one should have to use beautifulsoap or other technique to get data from this webpage.
#
# After getting an insight of average rental data of city, now we have to call the data for New York city have to explore.
#
# NYU students have created .json file for New York city data anyone can download it or call it in python plateform to do analysis.
#
# By using this command you can access this data as: !wget -q -O 'newyork_data.json' https://ibm.box.com/shared/static/fbpwbovar7lf8p5sgddm06cgipa2rxpe.json
#
# Anyone can get access to this dataset at NYU site as : https://geo.nyu.edu/catalog/nyu_2451_34572
#
# I have also uploaded this site in my github at : https://github.com/shakoor95/Coursera_Capstone/blob/master/newyork_data.json
#
# So, this is our raw data. We have to use Foursqure API to get venues of the neighborhoods of New York city, that you can have a look by watching final coding.
# The libraries that we will use in this project are as below:
#
# import folium
# import pandas as pd
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
# import numpy as np
# import requests
# from geopy.geocoders import Nominatim
# import json
#
#
# from pandas.io.json import json_normalize
#
# import matplotlib.cm as cm
# import matplotlib.colors as colors
#
#
# from sklearn.cluster import KMeans
#
#
#
# These are the libraries that we are going to use create datasets that we really needed.

# %% [markdown]
# # Battle of Neighborhoods-New York City (5 Borough city)
#
# In this capstone project, we will analyze New York City neighborhoods.
#
# Problem: As someone got a job or student is intersted to move NYC, He/She can utilize this data as described below.
#
#
# *All supporting files .csv files json files are uploaded in my github.
#
# Now lets start with importing libraries

# %%
import folium
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
import requests
from geopy.geocoders import Nominatim
import json


from pandas.io.json import json_normalize 

import matplotlib.cm as cm
import matplotlib.colors as colors


from sklearn.cluster import KMeans



print('Libraries got it')
# Out:
# Libraries got it

# %% [markdown]
# # Brooklyn, NY and Manhattan,NY rental data:
#
# Firstly we can access the rental data of different neighborhoods in all over the United States from the following website:
# https://www.rentcafe.com/average-rent-market-trends/us/ny/brooklyn/
#
# We have used this website to get an idea of rents going on the city of Brooklyn, NY and Manhattan (https://www.rentcafe.com/average-rent-market-trends/us/ny/manhattan/)
# But then we had to use beautifulsoap for web scrapping and prasing to get our desired data.
#
# I have saved  .csv files for both neighborhoods for convienience and you can see in the below cells to have an overview insight of New York city
#
# Brooklyn (https://github.com/shakoor95/Coursera_Capstone/blob/master/brooklyn.csv)
#
# Manhattan(https://github.com/shakoor95/Coursera_Capstone/blob/master/manhattan.csv)
#
# Bronx(https://github.com/shakoor95/Coursera_Capstone/blob/master/bronx.csv)

# %%
# reading New York city borough Brooklyn's neighborhoods in USD

file='brooklyn.csv'
a=pd.read_csv(file)
a
# Out:
#                            Neighborhood  Average Rent
# 0                             Flatlands          1492
# 1                           Marine Park          1659
# 2                               Madison          1659
# 3                       Gerritsen Beach          1659
# 4                             Homecrest          1717
# 5                           Bensonhurst          1795
# 6                            Bath Beach          1795
# 7                               Midwood          1825
# 8                         Fiske Terrace          1825
# 9                            Kensington          1839
# 10                            Gravesend          1840
# 11                        Crown Heights          1853
# 12                         Borough Park          1898
# 13                          Ditmas Park          1944
# 14                  Prospect Park South          1997
# 15          Prospect - Lefferts Gardens          2009
# ...

# %%
#Similarly we can have rental data of Manhattan,NY in USD as:

file2='Manhattan.csv'
b=pd.read_csv(file2)
b
# Out:
#                        Neighborhood  Average Rent
# 0                       Marble Hill          1694
# 1                            Inwood          2225
# 2                Washington Heights          2243
# 3        Randalls and Wards Islands          2336
# 4                       East Harlem          3334
# 5                        Tudor City          3338
# 6                  Roosevelt Island          3427
# 7                            Harlem          3604
# 8                    Liberty Island          3718
# 9                  Governors Island          3718
# 10                     Ellis Island          3718
# 11                  Stuyvesant Town          3720
# 12               Central Park South          3786
# 13  Theatre District - Times Square          3897
# 14                  Central Midtown          3913
# 15                       Turtle Bay          3973
# 16         Clinton - Hell's Kitchen          3991
# 17               Financial District          4005
# ...

# %% [markdown]
# # Exploring New York City
#
# As we initially got some idea about 2 big and fast neighborhoods of NYC in the above cells. Now, it's time to explore the city in depth so it would be easy for us to get settle down as per our requirements.
#
# As we can get New york data as we did one of the clustering lab in NYU research site. We can access that data as in the below cells and I have downloaded this data in my pc. So we can open it with open command.

# %%
# !wget -q -O 'newyork_data.json' https://ibm.box.com/shared/static/fbpwbovar7lf8p5sgddm06cgipa2rxpe.json
print('Data downloaded!')
# Out:
# Data downloaded!
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']

# %%
neighborhoods_data[0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %% [markdown]
# # Methodology
#
# Here it's the methodology that we followed in this project. Each step's details are mentioned below. As well as once we get all the neighborhoods of NYC. Then We will group them as per thier boroughs and then explore each borough completely and get venues information using foursqure API and then will filter top venues for each neighborhood and will conclude our project.

# %% [markdown]
# # As we know that New York city is 5 borough city. So now we are going to get dataframe of NYC in the form of boroughs with it's respective longitude and latitudes

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
neighborhoods
# Out:
#            Borough         Neighborhood   Latitude  Longitude
# 0            Bronx            Wakefield  40.894705 -73.847201
# 1            Bronx           Co-op City  40.874294 -73.829939
# 2            Bronx          Eastchester  40.887556 -73.827806
# 3            Bronx            Fieldston  40.895437 -73.905643
# 4            Bronx            Riverdale  40.890834 -73.912585
# 5            Bronx          Kingsbridge  40.881687 -73.902818
# 6        Manhattan          Marble Hill  40.876551 -73.910660
# 7            Bronx             Woodlawn  40.898273 -73.867315
# 8            Bronx              Norwood  40.877224 -73.879391
# 9            Bronx       Williamsbridge  40.881039 -73.857446
# 10           Bronx           Baychester  40.866858 -73.835798
# 11           Bronx       Pelham Parkway  40.857413 -73.854756
# 12           Bronx          City Island  40.847247 -73.786488
# 13           Bronx         Bedford Park  40.870185 -73.885512
# ...

# %% [markdown]
# Now we are going to locate New York city's LL as below

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent = 'my-application')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7308619, -73.9871558.

# %% [markdown]
# Now we have filtered Two boroughs of NYC : Queens and Brooklyn. Moreover, We will analyze Brooklyn. If someone wants to analyze other 4 boroughs of NYC he can do too using same technique.

# %%
queens_data = neighborhoods[neighborhoods['Borough'] == 'Queens'].reset_index(drop=True)
queens_data
# Out:
#    Borough          Neighborhood   Latitude  Longitude
# 0   Queens               Astoria  40.768509 -73.915654
# 1   Queens              Woodside  40.746349 -73.901842
# 2   Queens       Jackson Heights  40.751981 -73.882821
# 3   Queens              Elmhurst  40.744049 -73.881656
# 4   Queens          Howard Beach  40.654225 -73.838138
# 5   Queens                Corona  40.742382 -73.856825
# 6   Queens          Forest Hills  40.725264 -73.844475
# 7   Queens           Kew Gardens  40.705179 -73.829819
# 8   Queens         Richmond Hill  40.697947 -73.831833
# 9   Queens              Flushing  40.764454 -73.831773
# 10  Queens      Long Island City  40.750217 -73.939202
# 11  Queens             Sunnyside  40.740176 -73.926916
# 12  Queens         East Elmhurst  40.764073 -73.867041
# 13  Queens               Maspeth  40.725427 -73.896217
# 14  Queens             Ridgewood  40.708323 -73.901435
# 15  Queens              Glendale  40.702762 -73.870742
# ...

# %%
brooklyn_data = neighborhoods[neighborhoods['Borough'] == 'Brooklyn'].reset_index(drop=True)

brooklyn_data
# Out:
#      Borough               Neighborhood   Latitude  Longitude
# 0   Brooklyn                  Bay Ridge  40.625801 -74.030621
# 1   Brooklyn                Bensonhurst  40.611009 -73.995180
# 2   Brooklyn                Sunset Park  40.645103 -74.010316
# 3   Brooklyn                 Greenpoint  40.730201 -73.954241
# 4   Brooklyn                  Gravesend  40.595260 -73.973471
# 5   Brooklyn             Brighton Beach  40.576825 -73.965094
# 6   Brooklyn             Sheepshead Bay  40.586890 -73.943186
# 7   Brooklyn          Manhattan Terrace  40.614433 -73.957438
# 8   Brooklyn                   Flatbush  40.636326 -73.958401
# 9   Brooklyn              Crown Heights  40.670829 -73.943291
# 10  Brooklyn              East Flatbush  40.641718 -73.936103
# 11  Brooklyn                 Kensington  40.642382 -73.980421
# 12  Brooklyn            Windsor Terrace  40.656946 -73.980073
# 13  Brooklyn           Prospect Heights  40.676822 -73.964859
# ...

# %%
address = 'Queens, NY'

geolocator = Nominatim(user_agent = 'my-application')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Queens are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Queens are 40.6524927, -73.7914214158161.

# %%
address = 'Brooklyn, NY'

geolocator = Nominatim(user_agent = 'my-application')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Brooklyn are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Brooklyn are 40.6501038, -73.9495823.

# %% [markdown]
# Now we are going to get venues of NYC. But before moving forward we should have Foursquare developer account. Free tier account can work as well. The purpose of this account is that we need clientID and clientSecret and VERSION too for accessing venues from foursquare

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue',
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    print('Found {} venues in {} neighborhoods.'.format(nearby_venues.shape[0], len(venues_list)))
    
    return(nearby_venues)

# %%
CLIENT_ID = 'JLXZMZJP1VV5CLPAWH2PHI2VQQRVY5N1X0YVXYXAN23D2FC4' # your Foursquare ID
CLIENT_SECRET = '4NAPYVOOWR2P2U2KA1OP0G0EEQDYLS3Z1SGV1Y0B4YCTURGZ' # your Foursquare Secret
VERSION = '20190210'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: JLXZMZJP1VV5CLPAWH2PHI2VQQRVY5N1X0YVXYXAN23D2FC4
# CLIENT_SECRET:4NAPYVOOWR2P2U2KA1OP0G0EEQDYLS3Z1SGV1Y0B4YCTURGZ

# %%
brooklyn_venues = getNearbyVenues(names=brooklyn_data['Neighborhood'],
                                   latitudes=brooklyn_data['Latitude'],
                                   longitudes=brooklyn_data['Longitude'])
# Out:
# Found 1618 venues in 70 neighborhoods.

# %% [markdown]
# # Results
#
# Here we have executed the Foursquare API and following cells will give us our desired results.

# %%
brooklyn_venues
# Out:
#                    Neighborhood  Neighborhood Latitude  \
# 0                     Bay Ridge              40.625801
# 1                     Bay Ridge              40.625801
# 2                     Bay Ridge              40.625801
# 3                     Bay Ridge              40.625801
# 4                     Bay Ridge              40.625801
# 5                     Bay Ridge              40.625801
# 6                     Bay Ridge              40.625801
# 7                     Bay Ridge              40.625801
# 8                     Bay Ridge              40.625801
# 9                     Bay Ridge              40.625801
# 10                    Bay Ridge              40.625801
# 11                    Bay Ridge              40.625801
# 12                    Bay Ridge              40.625801
# 13                    Bay Ridge              40.625801
# 14                    Bay Ridge              40.625801
# 15                    Bay Ridge              40.625801
# ...

# %%
#Venues per Neighborhood
brooklyn_venues.groupby('Neighborhood').count()
# Out:
#                            Neighborhood Latitude  Neighborhood Longitude  \
# Neighborhood
# Bath Beach                                    30                      30
# Bay Ridge                                     30                      30
# Bedford Stuyvesant                            28                      28
# Bensonhurst                                   30                      30
# Bergen Beach                                   8                       8
# Boerum Hill                                   30                      30
# Borough Park                                  22                      22
# Brighton Beach                                30                      30
# Broadway Junction                             17                      17
# Brooklyn Heights                              30                      30
# Brownsville                                   17                      17
# Bushwick                                      30                      30
# ...

# %%
print('There are {} distinct venues in {} categories.'.format(
    len(brooklyn_venues['Venue'].unique()),len(brooklyn_venues['Venue Category'].unique())))
# Out:
# There are 1404 distinct venues in 237 categories.

# %%
# one hot encoding
brooklyn_onehot = pd.get_dummies(brooklyn_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
brooklyn_onehot['Neighborhood'] = brooklyn_venues['Neighborhood'] 


neighbor = brooklyn_onehot['Neighborhood']
brooklyn_onehot.drop(labels=['Neighborhood'], axis=1,inplace = True)
brooklyn_onehot.insert(0, 'Neighborhood', neighbor)

brooklyn_onehot

#using groupby to groupby all venues 

brooklyn_grouped = brooklyn_onehot.groupby('Neighborhood').mean().reset_index()
brooklyn_grouped
# Out:
#                  Neighborhood  American Restaurant  Antique Shop  \
# 0                  Bath Beach             0.000000      0.000000
# 1                   Bay Ridge             0.033333      0.000000
# 2          Bedford Stuyvesant             0.000000      0.000000
# 3                 Bensonhurst             0.000000      0.000000
# 4                Bergen Beach             0.000000      0.000000
# 5                 Boerum Hill             0.033333      0.033333
# 6                Borough Park             0.045455      0.000000
# 7              Brighton Beach             0.000000      0.000000
# 8           Broadway Junction             0.000000      0.000000
# 9            Brooklyn Heights             0.000000      0.000000
# 10                Brownsville             0.000000      0.000000
# 11                   Bushwick             0.000000      0.000000
# 12                   Canarsie             0.000000      0.000000
# ...

# %%
#Function to sort venues in descending order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]




num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = brooklyn_grouped['Neighborhood']

for ind in np.arange(brooklyn_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(brooklyn_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                  Neighborhood        1st Most Common Venue  \
# 0                  Bath Beach                   Kids Store
# 1                   Bay Ridge                  Pizza Place
# 2          Bedford Stuyvesant                  Coffee Shop
# 3                 Bensonhurst           Chinese Restaurant
# 4                Bergen Beach              Harbor / Marina
# 5                 Boerum Hill                  Yoga Studio
# 6                Borough Park                  Pizza Place
# 7              Brighton Beach  Eastern European Restaurant
# 8           Broadway Junction                Metro Station
# 9            Brooklyn Heights                  Yoga Studio
# 10                Brownsville                         Park
# 11                   Bushwick                          Bar
# 12                   Canarsie           Chinese Restaurant
# 13            Carroll Gardens                          Spa
# 14                  City Line                   Donut Shop
# ...

# %% [markdown]
# Here we have all overview of Brooklyn neighborhood. Anyone can analyze other 4 boroughs of NYC using same sterategy.
#
# As we have already gone through rental data of Brooklyn and Manhattan. We can have Bronx rental data as:

# %% [markdown]
# Bronx has relatievly cheap rents in NYC. Lets have average rental data of few neighborhoods as below and as well as I have uploaded rental data csv files in github too

# %%
file3='bronx.csv'
x=pd.read_csv(file3)
x
# Out:
#                         Neighborhood  Average Rent
# 0                     Spuyten Duyvil          1694
# 1                          Riverdale          1694
# 2  Kingsbridge Heights - Jerome Park          1694
# 3                        Kingsbridge          1694

# %% [markdown]
# # Conclusion and discussion
#
# Now it would be easy for anyone who is moving to New York City. As we have rental data and all venues too.
#
# As we are discussing this problem. Anyone can get rental data and neighborhoods details from the above mentioned codes and resultantly finds himself best match of Neighborhood as per your requiement for cafes, coffee shops, restrurants etc.
#
# This code is for brooklyn borough. We can use the extension of this code for other boroughs too and get rental data info from the website cited above.
